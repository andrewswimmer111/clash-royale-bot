# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 23.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import os
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="wNEnGMk4h0UpEhq3oEZF")
project = rf.workspace("andrewswimmer111").project("hog-2-6-new-arena-ey3ta")
version = project.version(4)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Hog-2.6-new-arena-4 in yolov8:: 100%|██████████| 434/434 [00:00<00:00, 7931.12it/s]

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-33a6e540-490e-4b7b-8892-a450bcff49e4" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-33a6e540-490e-4b7b-8892-a450bcff49e4">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !yolo task=detect mode=train model=/content/best.pt data={dataset.location}/data.yaml epochs=100 imgsz=512 patience=25 lr0=0.002
# Out:
# Ultralytics 8.3.232 🚀 Python-3.12.12 torch-2.9.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from IPython.display import Image
Image(filename='runs/detect/train2/confusion_matrix.png', width=600)
